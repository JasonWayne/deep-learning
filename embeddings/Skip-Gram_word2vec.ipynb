# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-15-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6960 0.0254 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5968 0.0214 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5200 0.0224 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5947 0.0220 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5415 0.0227 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5542 0.0220 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5626 0.0222 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5425 0.0222 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4713 0.0222 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4054 0.0223 sec/batch
# Nearest to on: authoritative, boingo, dench, balmoral, agitating, secaucus, homeostatic, dragsters,
# Nearest to an: substitute, donatello, mwali, observances, polyalphabetic, dissected, extremely, making,
# Nearest to with: diatonic, mails, affected, ampex, sardines, hovd, elusive, wheel,
# Nearest to seven: insolvency, layers, exalted, noticing, whore, allen, invaders, pavement,
# Nearest to were: albanians, mesaoria, complex, rebuilding, sonnenfeld, protective, riga, sihanouk,
# Nearest to about: cyclopentadienyl, baserunner, corolla, slumberland, diatessaron, assur, foray, usaid,
# Nearest to some: obrenovic, socio, lobos, layla, estate, approximate, custody, inhaling,
# Nearest to when: arbuthnot, ovation, straw, anaximenes, departure, prevailed, reactive, newspeak,
# Nearest to pre: retaliate, trowa, valine, convenient, adepts, highest, brigades, graves,
# Nearest to file: raptor, prot, rigoberta, cherubim, fmd, barricade, dioceses, indignant,
# Nearest to gold: impurity, obviously, phonetically, monitors, blow, sake, willem, hague,
# Nearest to magazine: unifies, excessively, misinformation, lateran, siblings, linear, forts, gibbs,
# Nearest to liberal: quail, unification, potentially, western, lhs, ciboney, pledging, enciclopedia,
# Nearest to http: abortions, europa, rastafari, ebony, piles, heimdall, gregarious, transpired,
# Nearest to arts: grs, cher, cabbage, powerbook, untouchable, provers, lawrence, vult,
# Nearest to mainly: bradley, processors, stresses, xxviii, byronic, woodville, doubts, sectioning,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4558 0.0224 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3790 0.0235 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3352 0.0228 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2103 0.0218 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1959 0.0222 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1455 0.0222 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0873 0.0215 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0690 0.0223 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9900 0.0216 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9600 0.0217 sec/batch
# Nearest to on: authoritative, similar, available, entire, us, agitating, examples, topic,
# Nearest to an: substitute, extremely, making, donatello, mainstream, absent, observances, mwali,
# Nearest to with: affected, mails, diatonic, elusive, peter, storm, wheel, biology,
# Nearest to seven: layers, insolvency, invaders, consequence, techniques, years, allen, pavement,
# Nearest to were: complex, protective, rebuilding, condoned, makers, priorities, then, having,
# Nearest to about: baserunner, projected, developers, requests, testament, contract, nearest, overshadowed,
# Nearest to some: socio, custody, lobos, intended, obrenovic, approximate, estate, permitted,
# Nearest to when: arbuthnot, straw, departure, self, high, ovation, gnu, anaximenes,
# Nearest to pre: highest, retaliate, convenient, go, performed, trowa, isbn, graves,
# Nearest to file: prot, raptor, conceptual, certainty, covering, barricade, impressed, minds,
# Nearest to gold: obviously, monitors, sake, impurity, blow, phonetically, casuistry, precisely,
# Nearest to magazine: unifies, excessively, misinformation, linear, already, joseph, forts, siblings,
# Nearest to liberal: western, unification, potentially, quail, ciboney, lhs, polishing, pledging,
# Nearest to http: europa, abortions, throne, rastafari, complementing, piles, caryophyllales, evidently,
# Nearest to arts: grs, cher, we, powerbook, gibson, restraint, untouchable, cabbage,
# Nearest to mainly: bradley, processors, stresses, xxviii, doubts, beloved, scheme, august,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9145 0.0237 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8844 0.0226 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8598 0.0231 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8460 0.0240 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8241 0.0219 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8046 0.0223 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8046 0.0221 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7801 0.0222 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7610 0.0214 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7891 0.0217 sec/batch
# Nearest to on: authoritative, topic, summon, homeostatic, dench, drains, progress, secaucus,
# Nearest to an: substitute, extremely, happiness, observances, making, symbolism, absent, donatello,
# Nearest to with: mails, diatonic, affected, elusive, spd, storm, numeral, wheel,
# Nearest to seven: allen, exalted, competing, noticing, layers, insolvency, whore, trnc,
# Nearest to were: protective, complex, makers, priorities, albanians, prescribed, rebuilding, stroke,
# Nearest to about: baserunner, projected, cyclopentadienyl, requests, contract, perennial, developers, usaid,
# Nearest to some: socio, permitted, custody, estate, layla, lobos, approximate, obrenovic,
# Nearest to when: arbuthnot, straw, prevailed, departure, ovation, reactive, self, high,
# Nearest to pre: convenient, retaliate, highest, trowa, go, phony, brigades, designing,
# Nearest to file: prot, raptor, certainty, satellites, covering, fmd, morals, impressed,
# Nearest to gold: obviously, sake, impurity, monitors, phonetically, blow, hague, screened,
# Nearest to magazine: unifies, misinformation, excessively, already, linear, siblings, enact, forts,
# Nearest to liberal: unification, western, potentially, quail, contributes, ciboney, inaugural, harboring,
# Nearest to http: europa, throne, abortions, evidently, piles, rastafari, toronto, notoc,
# Nearest to arts: grs, cher, unsettled, talking, restraint, powerbook, gibson, cabbage,
# Nearest to mainly: bradley, stresses, processors, beloved, doubts, xxviii, denoting, shining,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7726 0.0229 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7657 0.0216 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7075 0.0224 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7262 0.0216 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7231 0.0213 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6822 0.0216 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6807 0.0222 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7026 0.0217 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7306 0.0221 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6806 0.0217 sec/batch
# Nearest to on: authoritative, homeostatic, drains, summon, dench, secaucus, topic, module,
# Nearest to an: substitute, extremely, making, happiness, passionately, donatello, absent, mwali,
# Nearest to with: mails, diatonic, spd, sardines, elusive, affected, storm, wheel,
# Nearest to seven: trnc, allen, de, exalted, madagascar, rapper, years, encyclopedia,
# Nearest to were: albanians, protective, stroke, earthrise, condoned, complex, sacks, hildegard,
# Nearest to about: baserunner, projected, cyclopentadienyl, usaid, foray, slumberland, microphone, leptons,
# Nearest to some: socio, layla, permitted, custody, lobos, estate, cruelty, intended,
# Nearest to when: arbuthnot, reactive, straw, ovation, prevailed, departure, self, recalled,
# Nearest to pre: retaliate, convenient, trowa, adepts, phony, riverside, go, highest,
# Nearest to file: raptor, prot, certainty, satellites, covering, cherubim, fmd, indignant,
# Nearest to gold: impurity, obviously, phonetically, sake, hague, screened, monitors, spectacles,
# Nearest to magazine: misinformation, unifies, excessively, already, enact, siblings, hd, citing,
# Nearest to liberal: unification, ciboney, western, potentially, contributes, inaugural, lhs, harboring,
# Nearest to http: abortions, toronto, piles, europa, throne, styne, rastafari, notoc,
# Nearest to arts: grs, unsettled, untouchable, cher, phrasing, prompting, cabbage, powerbook,
# Nearest to mainly: bradley, stresses, processors, beloved, doubts, woodville, sectioning, shining,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6581 0.0230 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6398 0.0215 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6231 0.0223 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6304 0.0219 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6228 0.0215 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6459 0.0221 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5787 0.0163 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5471 0.0212 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5144 0.0227 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5062 0.0228 sec/batch
# Nearest to on: authoritative, homeostatic, drains, summon, dench, module, secaucus, topic,
# Nearest to an: substitute, extremely, happiness, absent, making, pw, passionately, donatello,
# Nearest to with: diatonic, sardines, mails, spd, elusive, numeral, affected, wheel,
# Nearest to seven: eight, one, six, trnc, de, actor, nine, b,
# Nearest to were: albanians, earthrise, sacks, complex, protective, stroke, highlanders, tricking,
# Nearest to about: baserunner, usaid, projected, slumberland, cyclopentadienyl, unmarked, foray, ak,
# Nearest to some: socio, layla, permitted, custody, lobos, cruelty, know, estate,
# Nearest to when: arbuthnot, ovation, reactive, straw, prevailed, departure, recalled, self,
# Nearest to pre: retaliate, convenient, trowa, phony, adepts, go, bibliographies, hens,
# Nearest to file: raptor, satellites, pda, indignant, prot, pasha, cherubim, fmd,
# Nearest to gold: impurity, phonetically, sake, screened, obviously, hague, monitors, intercultural,
# Nearest to magazine: misinformation, unifies, already, siblings, enact, excessively, hd, rationalists,
# Nearest to liberal: unification, ciboney, contributes, western, lhs, harboring, reptilian, inaugural,
# Nearest to http: abortions, toronto, online, www, styne, com, gregarious, notoc,
# Nearest to arts: grs, phrasing, cher, unsettled, untouchable, prompting, cabbage, gibson,
# Nearest to mainly: stresses, bradley, occident, woodville, processors, beloved, doubts, sectioning,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5009 0.0228 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5222 0.0223 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4697 0.0224 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5516 0.0218 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4969 0.0211 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4702 0.0219 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4691 0.0217 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3914 0.0211 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4218 0.0214 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4551 0.0210 sec/batch
# Nearest to on: homeostatic, authoritative, drains, summon, secaucus, dench, module, extort,
# Nearest to an: extremely, substitute, pw, passionately, absent, happiness, making, ethnicity,
# Nearest to with: diatonic, sardines, mails, alga, numeral, affected, wheel, ampex,
# Nearest to seven: trnc, allen, six, marmaduke, eight, rd, pearce, years,
# Nearest to were: albanians, earthrise, highlanders, protective, tricking, sacks, impurity, mesaoria,
# Nearest to about: baserunner, usaid, projected, leptons, cyclopentadienyl, slumberland, ak, aqueduct,
# Nearest to some: socio, layla, permitted, lobos, intended, cruelty, custody, know,
# Nearest to when: arbuthnot, reactive, ovation, prevailed, straw, departure, recalled, scrip,
# Nearest to pre: retaliate, convenient, phony, trowa, hens, adepts, flees, valine,
# Nearest to file: hardware, pda, raptor, satellites, indignant, interactive, fmd, pasha,
# Nearest to gold: impurity, screened, hague, fertilisation, phonetically, sake, animalia, ildefonso,
# Nearest to magazine: misinformation, unifies, excessively, siblings, already, enact, rationalists, biograph,
# Nearest to liberal: ciboney, unification, contributes, reptilian, western, enciclopedia, lhs, inaugural,
# Nearest to http: www, com, online, toronto, abortions, styne, notoc, reducible,
# Nearest to arts: grs, phrasing, untouchable, cher, unsettled, gibson, frantic, prompting,
# Nearest to mainly: stresses, doubts, woodville, occident, monorail, xxviii, bradley, shining,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4325 0.0217 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4072 0.0212 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4348 0.0212 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4067 0.0216 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3988 0.0219 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4774 0.0234 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3749 0.0225 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3855 0.0220 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3993 0.0225 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3578 0.0221 sec/batch
# Nearest to on: homeostatic, authoritative, summon, drains, theistic, secaucus, dench, tahoe,
# Nearest to an: pw, substitute, absent, extremely, making, happiness, charge, passionately,
# Nearest to with: diatonic, ampex, henan, mails, alga, harder, sardines, numeral,
# Nearest to seven: six, allen, trnc, one, rd, eight, pearce, zero,
# Nearest to were: earthrise, tricking, impurity, monoculture, highlanders, protective, sacks, albanians,
# Nearest to about: baserunner, slumberland, usaid, leptons, projected, cyclopentadienyl, ak, aqueduct,
# Nearest to some: socio, layla, permitted, intended, lobos, cruelty, know, reptites,
# Nearest to when: arbuthnot, reactive, ovation, prevailed, straw, departure, recalled, scrip,
# Nearest to pre: retaliate, convenient, trowa, phony, adepts, beginning, hens, valine,
# Nearest to file: hardware, raptor, pda, interactive, fmd, indignant, satellites, format,
# Nearest to gold: impurity, fertilisation, beneficiary, hague, animalia, screened, ildefonso, hagerstown,
# Nearest to magazine: misinformation, unifies, joseph, rationalists, already, biograph, siblings, photographer,
# Nearest to liberal: ciboney, unification, contributes, western, lhs, tailless, reptilian, amendment,
# Nearest to http: www, online, com, toronto, abortions, notoc, styne, https,
# Nearest to arts: grs, gibson, phrasing, cher, untouchable, frantic, scar, unsettled,
# Nearest to mainly: stresses, woodville, occident, destroys, doubts, monorail, xxviii, bius,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3924 0.0225 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3897 0.0221 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3642 0.0219 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3631 0.0229 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3859 0.0219 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3468 0.0222 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3992 0.0215 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3656 0.0221 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3356 0.0219 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3584 0.0224 sec/batch
# Nearest to on: summon, homeostatic, secaucus, authoritative, gaim, drains, bald, skids,
# Nearest to an: pw, substitute, absent, charge, passionately, extremely, making, happiness,
# Nearest to with: diatonic, henan, numeral, sardines, ampex, reestablish, kyushu, mails,
# Nearest to seven: six, eight, one, rd, zero, trnc, marmaduke, two,
# Nearest to were: albanians, retreated, earthrise, tricking, monoculture, epirus, various, seceding,
# Nearest to about: baserunner, slumberland, aqueduct, projected, leptons, usaid, shorelines, solely,
# Nearest to some: socio, layla, permitted, lobos, intended, cruelty, words, impatient,
# Nearest to when: arbuthnot, reactive, prevailed, straw, recalled, ovation, departure, scrip,
# Nearest to pre: retaliate, convenient, trowa, beginning, hens, phony, adepts, aerospatiale,
# Nearest to file: hardware, interactive, pda, raptor, format, fmd, documents, dos,
# Nearest to gold: impurity, beneficiary, animalia, mixtec, unexploited, fertilisation, intercultural, hagerstown,
# Nearest to magazine: misinformation, biograph, hd, rationalists, unifies, already, citing, poniatowski,
# Nearest to liberal: ciboney, unification, amendment, inaugural, contributes, tailless, reptilian, lhs,
# Nearest to http: www, com, online, https, toronto, notoc, abortions, org,
# Nearest to arts: grs, phrasing, gibson, cher, frantic, rhodes, provers, lawrence,
# Nearest to mainly: stresses, woodville, occident, vsl, bius, destroys, herding, monorail,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3376 0.0229 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2790 0.0218 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.4027 0.0231 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3867 0.0215 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4086 0.0216 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2718 0.0224 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3197 0.0228 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3623 0.0214 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1949 0.0223 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2733 0.0227 sec/batch
# Nearest to on: summon, telephony, secaucus, gaim, skids, homeostatic, authoritative, dench,
# Nearest to an: pw, absent, passionately, charge, substitute, erhalte, extremely, social,
# Nearest to with: diatonic, henan, sardines, mails, brezhoneg, kyushu, ampex, marisco,
# Nearest to seven: six, one, eight, rd, zero, two, trnc, allen,
# Nearest to were: tricking, albanians, earthrise, various, retreated, complex, protective, scarves,
# Nearest to about: baserunner, slumberland, aqueduct, usaid, leptons, projected, shorelines, solely,
# Nearest to some: socio, layla, lobos, permitted, cruelty, intended, ameliorate, admirably,
# Nearest to when: arbuthnot, reactive, straw, prevailed, recalled, ovation, departure, eiffel,
# Nearest to pre: retaliate, convenient, trowa, beginning, phony, aerospatiale, augustan, joost,
# Nearest to file: hardware, interactive, pda, raptor, dos, documents, fmd, format,
# Nearest to gold: impurity, beneficiary, animalia, unexploited, ildefonso, hagerstown, mixtec, fertilisation,
# Nearest to magazine: misinformation, biograph, photographer, rationalists, hd, already, joan, berrigan,
# Nearest to liberal: contributes, amendment, inaugural, unification, ciboney, tailless, enciclopedia, solemnly,
# Nearest to http: www, com, online, https, toronto, notoc, org, abortions,
# Nearest to arts: grs, phrasing, frantic, dtd, gibson, dedicate, faculty, provers,
# Nearest to mainly: stresses, woodville, occident, destroys, vsl, herding, sylia, doubts,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3273 0.0228 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3305 0.0228 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3238 0.0114 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2540 0.0217 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2388 0.0216 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2298 0.0233 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2220 0.0219 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1806 0.0217 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2339 0.0232 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1807 0.0219 sec/batch
# Nearest to on: gaim, skids, secaucus, dench, homeostatic, summon, telephony, bitmapped,
# Nearest to an: pw, charge, absent, erhalte, passionately, extremely, kaunas, wiretaps,
# Nearest to with: diatonic, henan, wheel, marisco, sardines, numeral, harder, kyushu,
# Nearest to seven: six, one, eight, rd, trnc, marmaduke, zero, two,
# Nearest to were: tricking, earthrise, albanians, retreated, epirus, various, highlanders, dahomey,
# Nearest to about: baserunner, slumberland, aqueduct, projected, usaid, leptons, km, kura,
# Nearest to some: socio, layla, lobos, permitted, cruelty, ameliorate, ecm, ineffectiveness,
# Nearest to when: arbuthnot, reactive, recalled, prevailed, straw, ovation, departure, remove,
# Nearest to pre: retaliate, convenient, trowa, phony, aerospatiale, augustan, marple, bibliographies,
# Nearest to file: raptor, pda, documents, interactive, fmd, hardware, format, pdf,
# Nearest to gold: impurity, beneficiary, animalia, mixtec, ildefonso, unexploited, hagerstown, fertilisation,
# Nearest to magazine: misinformation, biograph, photographer, rationalists, hd, joan, berrigan, already,
# Nearest to liberal: inaugural, unification, amendment, ciboney, solemnly, contributes, tailless, enciclopedia,
# Nearest to http: www, com, online, https, org, toronto, notoc, abortions,
# Nearest to arts: phrasing, grs, faculty, gibson, honours, dtd, dedicate, frantic,
# Nearest to mainly: woodville, stresses, occident, voiceless, also, sylia, destroys, downsized,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2338 0.0237 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2123 0.0226 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2267 0.0224 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1308 0.0229 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1847 0.0214 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1791 0.0232 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1539 0.0225 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2034 0.0221 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2109 0.0234 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1829 0.0224 sec/batch
# Nearest to on: gaim, skids, homeostatic, secaucus, bitmapped, dench, drains, tahoe,
# Nearest to an: pw, absent, charge, erhalte, passionately, necessitates, social, making,
# Nearest to with: diatonic, henan, wheel, harder, marisco, sardines, ampex, alga,
# Nearest to seven: six, rd, one, zero, two, eight, marmaduke, five,
# Nearest to were: tricking, protective, retreated, dahomey, epirus, earthrise, scarves, various,
# Nearest to about: baserunner, slumberland, leptons, projected, aqueduct, km, usaid, solely,
# Nearest to some: socio, layla, permitted, lobos, cruelty, intended, stress, ecm,
# Nearest to when: reactive, arbuthnot, straw, recalled, prevailed, ovation, remove, fpgas,
# Nearest to pre: retaliate, convenient, trowa, aerospatiale, phony, marple, eas, runes,
# Nearest to file: pda, documents, raptor, interactive, format, fmd, mime, dos,
# Nearest to gold: impurity, mixtec, beneficiary, unexploited, fertilisation, animalia, hagerstown, ildefonso,
# Nearest to magazine: biograph, misinformation, photographer, hd, rationalists, cute, burt, poniatowski,
# Nearest to liberal: unification, solemnly, contributes, ciboney, amendment, western, inaugural, tailless,
# Nearest to http: www, com, https, online, toronto, org, notoc, htm,
# Nearest to arts: phrasing, grs, faculty, honours, dtd, gibson, dedicate, rhodes,
# Nearest to mainly: occident, stresses, byronic, also, woodville, voiceless, vsl, destroys,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1817 0.0233 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2524 0.0231 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.2052 0.0220 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1631 0.0217 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1892 0.0221 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1806 0.0226 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2038 0.0223 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1733 0.0222 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1407 0.0219 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1556 0.0215 sec/batch
# Nearest to on: gaim, skids, tahoe, secaucus, homeostatic, dench, kliment, extort,
# Nearest to an: absent, charge, geeks, pw, of, erhalte, necessitates, social,
# Nearest to with: diatonic, henan, harder, wheel, numeral, kyushu, marisco, indo,
# Nearest to seven: six, one, zero, eight, two, rd, five, years,
# Nearest to were: tricking, retreated, protective, earthrise, various, scarves, mapmakers, mesaoria,
# Nearest to about: baserunner, slumberland, projected, aqueduct, leptons, solely, kura, usaid,
# Nearest to some: socio, layla, lobos, permitted, cruelty, intended, stress, custody,
# Nearest to when: reactive, arbuthnot, straw, recalled, prevailed, ovation, remove, departure,
# Nearest to pre: retaliate, convenient, trowa, aerospatiale, bibliographies, pectoral, marple, eas,
# Nearest to file: documents, interactive, pda, raptor, mime, format, fmd, dos,
# Nearest to gold: impurity, beneficiary, unexploited, fertilisation, mixtec, autocannon, ildefonso, minted,
# Nearest to magazine: biograph, misinformation, photographer, rationalists, burt, hd, cute, poniatowski,
# Nearest to liberal: solemnly, contributes, unification, inaugural, ciboney, tailless, western, amendment,
# Nearest to http: www, com, https, online, htm, notoc, org, toronto,
# Nearest to arts: phrasing, faculty, grs, honours, expatriate, dtd, dedicate, gibson,
# Nearest to mainly: also, occident, stresses, woodville, vsl, downsized, excerpted, byronic,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2283 0.0229 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1599 0.0222 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1909 0.0221 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1547 0.0217 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1724 0.0213 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1233 0.0228 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1768 0.0219 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0960 0.0227 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1920 0.0221 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2093 0.0212 sec/batch
# Nearest to on: the, gaim, skids, dench, secaucus, invitation, tahoe, brattle,
# Nearest to an: absent, erhalte, charge, social, passionately, pw, geeks, of,
# Nearest to with: henan, marisco, diatonic, to, kyushu, wheel, everyone, harder,
# Nearest to seven: six, one, two, zero, eight, rd, five, three,
# Nearest to were: various, tricking, retreated, epirus, highlanders, lay, protective, horrific,
# Nearest to about: slumberland, baserunner, aqueduct, projected, km, leptons, usaid, kura,
# Nearest to some: socio, layla, lobos, permitted, cruelty, custody, intended, words,
# Nearest to when: arbuthnot, recalled, reactive, straw, prevailed, ovation, guip, tupper,
# Nearest to pre: retaliate, convenient, trowa, aerospatiale, eas, mausoleum, marple, bibliographies,
# Nearest to file: documents, mime, raptor, pda, interactive, fmd, format, pdf,
# Nearest to gold: impurity, beneficiary, unexploited, mixtec, bauxite, fertilisation, ildefonso, sake,
# Nearest to magazine: biograph, misinformation, photographer, rationalists, vega, berrigan, hd, joan,
# Nearest to liberal: unification, inaugural, contributes, solemnly, tailless, ciboney, enciclopedia, hold,
# Nearest to http: www, https, com, htm, online, org, notoc, html,
# Nearest to arts: phrasing, faculty, grs, honours, dtd, dedicate, festival, expatriate,
# Nearest to mainly: vsl, excerpted, also, occident, voiceless, woodville, byronic, shining,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2338 0.0231 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1066 0.0220 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1535 0.0222 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1585 0.0230 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0352 0.0234 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1386 0.0211 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1491 0.0212 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1509 0.0229 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1775 0.0047 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1056 0.0204 sec/batch
# Nearest to on: gaim, the, skids, tahoe, secaucus, dench, kliment, invitation,
# Nearest to an: absent, erhalte, geeks, charge, pw, re, of, a,
# Nearest to with: diatonic, henan, wheel, kyushu, marisco, to, harder, alga,
# Nearest to seven: six, one, two, zero, eight, five, rd, three,
# Nearest to were: tricking, various, protective, retreated, highlanders, albanians, possibly, impurity,
# Nearest to about: baserunner, aqueduct, km, kura, slumberland, projected, leptons, usaid,
# Nearest to some: socio, layla, lobos, permitted, meson, cruelty, intended, stress,
# Nearest to when: arbuthnot, reactive, recalled, prevailed, straw, ovation, guip, unstable,
# Nearest to pre: retaliate, convenient, trowa, aerospatiale, bibliographies, eas, marple, shares,
# Nearest to file: documents, mime, raptor, interactive, pda, format, pdf, fmd,
# Nearest to gold: impurity, beneficiary, unexploited, ildefonso, sake, bauxite, mixtec, hagerstown,
# Nearest to magazine: biograph, misinformation, photographer, hd, rationalists, cute, vega, berrigan,
# Nearest to liberal: contributes, unification, solemnly, inaugural, tailless, enciclopedia, ciboney, western,
# Nearest to http: www, https, com, htm, online, org, edu, notoc,
# Nearest to arts: phrasing, faculty, grs, dtd, martial, expatriate, honours, dedicate,
# Nearest to mainly: also, excerpted, vsl, occident, voiceless, byronic, downsized, sylia,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0877 0.0222 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0679 0.0221 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0962 0.0212 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0468 0.0212 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0888 0.0233 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0273 0.0234 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0868 0.0242 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0959 0.0221 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1143 0.0230 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0159 0.0226 sec/batch
# Nearest to on: gaim, secaucus, tahoe, the, skids, drains, extort, newsreels,
# Nearest to an: charge, of, absent, a, erhalte, pw, geeks, social,
# Nearest to with: diatonic, to, wheel, alga, numeral, harder, marisco, and,
# Nearest to seven: six, one, two, zero, five, rd, eight, three,
# Nearest to were: retreated, epirus, various, possibly, tricking, protective, highlanders, crusaders,
# Nearest to about: aqueduct, kura, projected, km, baserunner, slumberland, leptons, usaid,
# Nearest to some: socio, layla, lobos, permitted, meson, limited, cruelty, intended,
# Nearest to when: reactive, arbuthnot, prevailed, recalled, straw, unstable, ovation, remove,
# Nearest to pre: retaliate, convenient, trowa, aerospatiale, bibliographies, eas, petropavlovsk, steeply,
# Nearest to file: documents, mime, pda, raptor, interactive, arexx, fmd, format,
# Nearest to gold: impurity, beneficiary, mixtec, ildefonso, unexploited, sake, hagerstown, minted,
# Nearest to magazine: biograph, misinformation, rationalists, hd, photographer, cute, burt, joan,
# Nearest to liberal: solemnly, contributes, unification, inaugural, tailless, ciboney, enciclopedia, western,
# Nearest to http: www, https, com, htm, org, online, edu, html,
# Nearest to arts: faculty, phrasing, grs, martial, dtd, honours, expatriate, festival,
# Nearest to mainly: also, excerpted, vsl, voiceless, occident, rapid, atomists, downsized,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0575 0.0222 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0189 0.0223 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9972 0.0225 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0583 0.0213 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0695 0.0214 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0588 0.0222 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0734 0.0216 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1116 0.0218 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0607 0.0221 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0551 0.0209 sec/batch
# Nearest to on: gaim, the, skids, tahoe, secaucus, extort, dench, normals,
# Nearest to an: of, charge, a, absent, pw, erhalte, social, nath,
# Nearest to with: diatonic, to, wheel, alga, henan, and, numeral, harder,
# Nearest to seven: six, one, two, five, zero, eight, three, rd,
# Nearest to were: various, protective, tricking, highlanders, expansion, retreated, scarves, epirus,
# Nearest to about: projected, baserunner, km, leptons, slumberland, kura, aqueduct, usaid,
# Nearest to some: socio, layla, lobos, permitted, stress, meson, intended, many,
# Nearest to when: reactive, arbuthnot, recalled, prevailed, straw, unstable, ovation, remove,
# Nearest to pre: retaliate, trowa, aerospatiale, convenient, bibliographies, eas, marple, steeply,
# Nearest to file: documents, mime, pda, raptor, arexx, interactive, fmd, pdf,
# Nearest to gold: impurity, beneficiary, silver, mixtec, ildefonso, obverse, unexploited, sake,
# Nearest to magazine: biograph, misinformation, photographer, rationalists, hd, joan, vega, stories,
# Nearest to liberal: solemnly, contributes, unification, western, hold, tailless, inaugural, enciclopedia,
# Nearest to http: www, https, com, htm, org, online, edu, notoc,
# Nearest to arts: faculty, phrasing, grs, expatriate, dtd, honours, festival, martial,
# Nearest to mainly: also, voiceless, vsl, excerpted, neogrammarians, dorset, occident, byronic,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0624 0.0228 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0705 0.0222 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1095 0.0215 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0480 0.0226 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0671 0.0222 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0763 0.0228 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0971 0.0209 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0720 0.0214 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0948 0.0229 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0735 0.0225 sec/batch
# Nearest to on: gaim, skids, the, extort, secaucus, convicted, dench, newsreels,
# Nearest to an: of, absent, charge, erhalte, a, social, adnan, pw,
# Nearest to with: to, wheel, diatonic, and, henan, bioavailability, the, brezhoneg,
# Nearest to seven: six, one, two, five, zero, eight, three, years,
# Nearest to were: various, epirus, retreated, possibly, protective, highlanders, expansion, tricking,
# Nearest to about: projected, baserunner, km, slumberland, kura, aqueduct, usaid, leptons,
# Nearest to some: socio, layla, lobos, permitted, intended, many, stress, polyandry,
# Nearest to when: reactive, arbuthnot, recalled, prevailed, straw, unstable, guip, remove,
# Nearest to pre: retaliate, convenient, trowa, aerospatiale, bibliographies, eas, beginning, petropavlovsk,
# Nearest to file: documents, mime, pda, interactive, arexx, pdf, raptor, format,
# Nearest to gold: impurity, beneficiary, unexploited, obverse, minted, silver, ildefonso, bauxite,
# Nearest to magazine: biograph, misinformation, rationalists, hd, stories, photographer, joan, vega,
# Nearest to liberal: solemnly, contributes, unification, western, inaugural, enciclopedia, ralph, irs,
# Nearest to http: www, https, com, htm, org, online, edu, html,
# Nearest to arts: faculty, phrasing, martial, grs, festival, dtd, honours, expatriate,
# Nearest to mainly: also, vsl, excerpted, neogrammarians, voiceless, occident, atomists, byronic,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0392 0.0231 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0013 0.0226 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0083 0.0230 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0713 0.0208 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0814 0.0217 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1268 0.0225 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1268 0.0235 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0225 0.0232 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0346 0.0232 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0820 0.0223 sec/batch
# Nearest to on: the, gaim, skids, newsreels, extort, alexandra, dench, secaucus,
# Nearest to an: absent, charge, of, a, social, pw, erhalte, the,
# Nearest to with: henan, wheel, to, marisco, diatonic, bioavailability, and, brezhoneg,
# Nearest to seven: six, one, two, zero, eight, five, three, nine,
# Nearest to were: various, protective, tricking, epirus, mok, horrific, retreated, highlanders,
# Nearest to about: projected, baserunner, slumberland, km, aqueduct, usaid, leptons, menial,
# Nearest to some: socio, layla, lobos, permitted, limited, many, intended, polyandry,
# Nearest to when: arbuthnot, recalled, reactive, straw, prevailed, unstable, guip, earthlike,
# Nearest to pre: retaliate, convenient, eas, trowa, aerospatiale, bibliographies, marple, runes,
# Nearest to file: documents, mime, pda, pdf, format, interactive, raptor, djvu,
# Nearest to gold: impurity, beneficiary, silver, unexploited, ildefonso, obverse, bauxite, minted,
# Nearest to magazine: biograph, misinformation, photographer, rationalists, stories, vega, hd, joan,
# Nearest to liberal: contributes, solemnly, unification, inaugural, western, tutoring, cnrs, irs,
# Nearest to http: www, https, htm, com, org, edu, html, online,
# Nearest to arts: faculty, phrasing, martial, budo, dtd, festival, honours, grs,
# Nearest to mainly: vsl, also, excerpted, byronic, occident, rapid, neogrammarians, voiceless,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9573 0.0234 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0091 0.0229 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0236 0.0229 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0546 0.0235 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0616 0.0223 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0217 0.0229 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0091 0.0230 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9972 0.0227 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0217 0.0228 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9709 0.0225 sec/batch
# Nearest to on: gaim, the, skids, newsreels, extort, dench, alexandra, kliment,
# Nearest to an: absent, charge, a, pw, adnan, of, geeks, phonics,
# Nearest to with: to, wheel, marisco, henan, and, alga, diatonic, brezhoneg,
# Nearest to seven: six, one, two, zero, five, three, eight, nine,
# Nearest to were: epirus, protective, various, tricking, highlanders, horrific, possibly, retreated,
# Nearest to about: projected, km, baserunner, slumberland, kura, aqueduct, leptons, usaid,
# Nearest to some: socio, layla, lobos, permitted, polyandry, limited, meson, intended,
# Nearest to when: recalled, arbuthnot, prevailed, reactive, unstable, guip, straw, remove,
# Nearest to pre: retaliate, convenient, trowa, bibliographies, aerospatiale, eas, runes, verily,
# Nearest to file: mime, documents, pda, format, pdf, raptor, djvu, fmd,
# Nearest to gold: impurity, beneficiary, silver, undertaker, minted, obverse, sake, ildefonso,
# Nearest to magazine: biograph, misinformation, rationalists, stories, hd, vega, photographer, worldcon,
# Nearest to liberal: contributes, solemnly, unification, western, ralph, tutoring, inaugural, cnrs,
# Nearest to http: www, https, htm, com, org, html, edu, notoc,
# Nearest to arts: faculty, phrasing, martial, budo, dtd, festival, schools, expatriate,
# Nearest to mainly: also, vsl, excerpted, voiceless, neogrammarians, byronic, dorset, sylia,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9864 0.0226 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9524 0.0223 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0244 0.0224 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0205 0.0216 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0154 0.0228 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9753 0.0220 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9228 0.0223 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9657 0.0223 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9152 0.0223 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9856 0.0215 sec/batch
# Nearest to on: the, gaim, newsreels, extort, post, routers, incisors, skids,
# Nearest to an: a, absent, of, charge, the, pw, culpa, adnan,
# Nearest to with: alga, and, to, marisco, the, wheel, which, henan,
# Nearest to seven: six, one, zero, two, five, three, eight, nine,
# Nearest to were: protective, various, epirus, highlanders, possibly, retreated, mok, expansion,
# Nearest to about: projected, km, slumberland, zero, baserunner, kura, ak, interplanetary,
# Nearest to some: layla, socio, lobos, permitted, polyandry, limited, intended, diversity,
# Nearest to when: recalled, prevailed, reactive, arbuthnot, unstable, guip, straw, remove,
# Nearest to pre: retaliate, aerospatiale, trowa, convenient, bibliographies, eas, zoos, runes,
# Nearest to file: mime, documents, pda, arexx, format, adware, raptor, djvu,
# Nearest to gold: impurity, beneficiary, silver, undertaker, bauxite, ildefonso, minted, mixtec,
# Nearest to magazine: biograph, misinformation, rationalists, stories, vega, hd, photographer, published,
# Nearest to liberal: contributes, solemnly, western, unification, ralph, nationalists, coalition, tutoring,
# Nearest to http: www, https, htm, com, org, notoc, edu, html,
# Nearest to arts: faculty, phrasing, martial, budo, festival, schools, expatriate, dtd,
# Nearest to mainly: also, vsl, dorset, breakup, excerpted, stad, atomists, voiceless,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0165 0.0230 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0014 0.0228 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9750 0.0230 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9925 0.0220 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0356 0.0218 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9624 0.0221 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0140 0.0219 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9865 0.0220 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9996 0.0218 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0236 0.0222 sec/batch
# Nearest to on: the, gaim, newsreels, post, dench, extort, routers, skids,
# Nearest to an: absent, of, a, charge, pw, the, culpa, phonics,
# Nearest to with: to, and, alga, the, marisco, wheel, diatonic, which,
# Nearest to seven: six, one, two, zero, eight, five, three, nine,
# Nearest to were: various, protective, trypho, possibly, highlanders, epirus, mapmakers, lay,
# Nearest to about: slumberland, kura, projected, baserunner, km, bible, zoster, reincarnations,
# Nearest to some: socio, layla, permitted, lobos, polyandry, intended, limited, diversity,
# Nearest to when: reactive, recalled, straw, earthlike, unstable, arbuthnot, prevailed, guip,
# Nearest to pre: retaliate, aerospatiale, convenient, trowa, eas, bibliographies, riverside, shares,
# Nearest to file: documents, mime, format, pda, adware, arexx, pdf, files,
# Nearest to gold: impurity, beneficiary, silver, undertaker, ildefonso, minted, obverse, bauxite,
# Nearest to magazine: biograph, stories, misinformation, rationalists, vega, joan, photographer, poniatowski,
# Nearest to liberal: contributes, western, solemnly, unification, ralph, cnrs, nationalists, tutoring,
# Nearest to http: www, https, htm, com, org, html, notoc, edu,
# Nearest to arts: faculty, phrasing, martial, budo, festival, expatriate, dtd, schools,
# Nearest to mainly: also, vsl, atomists, voiceless, excerpted, dorset, breakup, neogrammarians,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0382 0.0225 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9901 0.0222 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9846 0.0227 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0198 0.0234 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0310 0.0216 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0054 0.0223 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9897 0.0224 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9484 0.0213 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9805 0.0220 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0295 0.0217 sec/batch
# Nearest to on: the, gaim, routers, newsreels, post, extort, default, invitation,
# Nearest to an: a, of, absent, pw, the, phonics, charge, erhalte,
# Nearest to with: to, and, the, which, marisco, wheel, sq, henan,
# Nearest to seven: six, one, two, zero, five, three, eight, nine,
# Nearest to were: various, possibly, highlanders, protective, quell, lay, survived, epirus,
# Nearest to about: projected, slumberland, km, kura, zero, vaishnavite, usaid, baserunner,
# Nearest to some: socio, layla, lobos, polyandry, permitted, limited, intended, many,
# Nearest to when: recalled, unstable, straw, guip, arbuthnot, earthlike, reactive, prevailed,
# Nearest to pre: retaliate, eas, aerospatiale, trowa, convenient, riverside, shares, petropavlovsk,
# Nearest to file: mime, documents, format, arexx, pdf, adware, pda, fmd,
# Nearest to gold: impurity, beneficiary, silver, undertaker, minted, ildefonso, obverse, bauxite,
# Nearest to magazine: biograph, stories, vega, misinformation, published, hd, rationalists, djvu,
# Nearest to liberal: unification, solemnly, ralph, western, contributes, cnrs, tutoring, ciboney,
# Nearest to http: www, https, htm, com, org, html, notoc, edu,
# Nearest to arts: faculty, phrasing, martial, budo, festival, expatriate, dtd, schools,
# Nearest to mainly: also, vsl, atomists, dorset, breakup, voiceless, surnames, excerpted,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9521 0.0221 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0694 0.0219 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0310 0.0216 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0360 0.0212 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9563 0.0212 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9632 0.0217 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9939 0.0217 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9299 0.0220 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9715 0.0218 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9668 0.0220 sec/batch
# Nearest to on: the, gaim, by, of, from, newsreels, skids, post,
# Nearest to an: a, of, pw, the, phonics, absent, charge, culpa,
# Nearest to with: and, to, the, henan, wheel, marisco, which, brezhoneg,
# Nearest to seven: six, one, two, zero, three, five, eight, nine,
# ...
# Nearest to magazine: magazines, published, news, stories, biograph, rationalists, worldcon, erasable,
# Nearest to liberal: ralph, coalition, democrat, party, conservative, unification, eliza, cnrs,
# Nearest to http: www, htm, https, org, com, cfm, html, edu,
# Nearest to arts: budo, martial, shaolin, faculty, muay, phrasing, travertine, dojo,
# Nearest to mainly: also, are, cotonou, vsl, through, colonized, elul, shining,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8696 0.0233 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7408 0.0229 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8357 0.0229 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7907 0.0225 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8371 0.0241 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8623 0.0240 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8394 0.0241 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8170 0.0233 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8764 0.0231 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9363 0.0224 sec/batch
# Nearest to on: the, of, from, which, by, in, a, all,
# Nearest to an: the, a, of, is, in, for, and, to,
# Nearest to with: to, and, the, a, which, in, both, of,
# Nearest to seven: six, one, eight, five, three, zero, two, four,
# Nearest to were: they, taxonomies, mapmakers, have, been, possibly, various, was,
# Nearest to about: zero, updike, romanek, chimaera, blavatsky, projected, life, roosevelts,
# Nearest to some: many, such, that, these, are, though, based, the,
# Nearest to when: a, the, in, to, on, earthlike, by, caesarion,
# Nearest to pre: conquest, beginning, eventually, exported, mixtec, zoos, petropavlovsk, rede,
# Nearest to file: mime, format, files, documents, adware, disclosures, arexx, append,
# Nearest to gold: silver, impurity, beneficiary, undertaker, pharmacies, minted, congo, ildefonso,
# Nearest to magazine: magazines, published, stories, news, erasable, rationalists, biography, placards,
# Nearest to liberal: ralph, coalition, conservative, cnrs, party, democrat, unification, vegetation,
# Nearest to http: www, htm, https, com, org, cfm, html, web,
# Nearest to arts: budo, martial, shaolin, faculty, muay, obsolescence, phrasing, travertine,
# Nearest to mainly: also, are, cotonou, colonized, vsl, elul, klezmer, fully,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8374 0.0234 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8770 0.0235 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8472 0.0230 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8463 0.0231 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8661 0.0221 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8677 0.0226 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8282 0.0223 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8571 0.0228 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8684 0.0229 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8800 0.0231 sec/batch
# Nearest to on: the, from, of, by, which, in, first, an,
# Nearest to an: the, a, of, in, is, for, and, to,
# Nearest to with: to, and, the, a, which, in, of, both,
# Nearest to seven: six, one, eight, five, two, zero, three, four,
# Nearest to were: they, in, mapmakers, was, been, taxonomies, least, than,
# Nearest to about: zero, updike, lique, chimaera, knitters, projected, romanek, blavatsky,
# Nearest to some: many, such, these, that, are, based, and, they,
# Nearest to when: a, in, nearest, on, the, after, princess, more,
# Nearest to pre: conquest, beginning, eventually, exported, mixtec, petropavlovsk, convenient, rede,
# Nearest to file: mime, documents, format, files, adware, disclosures, cherubim, pdf,
# Nearest to gold: silver, beneficiary, impurity, minted, pharmacies, undertaker, congo, ildefonso,
# Nearest to magazine: magazines, published, news, erasable, stories, poniatowski, rationalists, djvu,
# Nearest to liberal: ralph, cnrs, coalition, conservative, party, unification, eliza, hold,
# Nearest to http: www, htm, https, org, com, cfm, edu, html,
# Nearest to arts: budo, martial, shaolin, faculty, muay, obsolescence, phrasing, travertine,
# Nearest to mainly: also, are, cotonou, colonized, through, vsl, elul, fully,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8727 0.0233 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8531 0.0233 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8227 0.0231 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8031 0.0231 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8955 0.0227 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8300 0.0234 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9801 0.0235 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8821 0.0243 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9221 0.0238 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8038 0.0229 sec/batch
# Nearest to on: the, of, in, by, which, from, first, an,
# Nearest to an: the, a, of, in, and, is, for, known,
# Nearest to with: to, and, the, a, which, in, of, both,
# Nearest to seven: six, one, zero, two, eight, five, three, four,
# Nearest to were: they, was, have, in, been, capitulate, taxonomies, including,
# Nearest to about: zero, updike, my, croatians, romanek, roosevelts, chimaera, projected,
# Nearest to some: such, many, these, that, custody, accepting, are, they,
# Nearest to when: a, in, after, the, on, to, princess, during,
# Nearest to pre: exported, conquest, petropavlovsk, mixtec, eventually, beginning, eas, dept,
# Nearest to file: mime, format, documents, files, adware, pdf, cherubim, disclosures,
# Nearest to gold: silver, beneficiary, impurity, minted, undertaker, pharmacies, congo, ildefonso,
# Nearest to magazine: magazines, published, news, erasable, librarians, stories, biograph, poniatowski,
# Nearest to liberal: ralph, coalition, conservative, cnrs, unification, hotline, democrat, party,
# Nearest to http: www, htm, https, org, com, cfm, edu, html,
# Nearest to arts: budo, martial, muay, shaolin, faculty, phrasing, striking, crafts,
# Nearest to mainly: also, are, cotonou, vsl, colonized, fully, through, elul,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7879 0.0237 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8533 0.0229 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7951 0.0244 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8644 0.0230 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8476 0.0227 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8765 0.0225 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8441 0.0153 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8339 0.0234 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8229 0.0241 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8735 0.0228 sec/batch
# Nearest to on: the, by, of, in, from, which, first, for,
# Nearest to an: the, a, of, in, is, for, and, to,
# Nearest to with: to, and, the, a, which, in, of, both,
# Nearest to seven: six, one, eight, two, five, three, zero, four,
# Nearest to were: they, have, been, in, the, was, taxonomies, for,
# Nearest to about: zero, croatians, romanek, updike, lique, km, roosevelts, projected,
# Nearest to some: such, many, these, that, also, have, and, are,
# Nearest to when: a, after, princess, the, on, in, nearest, more,
# Nearest to pre: conquest, exported, beginning, eventually, petropavlovsk, mixtec, pueblo, eas,
# Nearest to file: format, mime, files, documents, adware, pdf, cherubim, disclosures,
# Nearest to gold: silver, beneficiary, impurity, minted, undertaker, congo, pharmacies, platinum,
# Nearest to magazine: magazines, published, news, erasable, stories, biography, librarians, djvu,
# Nearest to liberal: ralph, conservative, cnrs, unification, coalition, hotline, hold, eliza,
# Nearest to http: www, htm, https, org, com, cfm, web, edu,
# Nearest to arts: budo, martial, shaolin, muay, faculty, striking, fighting, obsolescence,
# Nearest to mainly: also, are, cotonou, fully, vsl, excerpted, colonized, elul,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8069 0.0235 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8239 0.0235 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7909 0.0241 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8225 0.0235 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8699 0.0238 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8225 0.0232 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8950 0.0232 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7456 0.0231 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8130 0.0240 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7925 0.0233 sec/batch
# Nearest to on: the, from, of, in, which, by, first, all,
# Nearest to an: the, a, of, is, in, for, and, to,
# Nearest to with: to, and, the, a, which, in, of, from,
# Nearest to seven: six, one, five, eight, three, zero, two, four,
# Nearest to were: they, have, been, was, taxonomies, mapmakers, least, in,
# Nearest to about: zero, updike, romanek, merneptah, chimaera, life, lique, requires,
# Nearest to some: such, these, many, are, that, and, based, have,
# Nearest to when: a, on, in, after, the, more, to, for,
# Nearest to pre: exported, eventually, beginning, conquest, mixtec, petropavlovsk, eas, rede,
# Nearest to file: format, mime, files, documents, adware, disclosures, cherubim, arexx,
# Nearest to gold: silver, impurity, beneficiary, minted, congo, undertaker, ildefonso, pharmacies,
# Nearest to magazine: magazines, published, news, biography, erasable, stories, biograph, worldcon,
# Nearest to liberal: ralph, conservative, coalition, cnrs, party, hotline, eliza, unification,
# Nearest to http: www, htm, https, org, com, cfm, html, web,
# Nearest to arts: budo, martial, muay, shaolin, faculty, striking, obsolescence, phrasing,
# Nearest to mainly: also, are, cotonou, fully, vsl, colonized, through, nilo,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7996 0.0240 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8190 0.0229 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8386 0.0224 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8076 0.0229 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8336 0.0217 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9020 0.0215 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7998 0.0225 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8220 0.0221 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8535 0.0229 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8474 0.0232 sec/batch
# Nearest to on: the, of, in, by, which, from, a, an,
# Nearest to an: the, a, of, is, in, for, and, to,
# Nearest to with: to, and, the, a, which, in, of, both,
# Nearest to seven: six, one, eight, five, zero, three, two, four,
# Nearest to were: they, have, been, was, least, than, mapmakers, taxonomies,
# Nearest to about: zero, updike, lique, romanek, links, my, life, projected,
# Nearest to some: such, many, these, have, based, are, also, and,
# Nearest to when: a, after, in, the, on, for, with, to,
# Nearest to pre: exported, eventually, conquest, beginning, mixtec, petropavlovsk, modern, eas,
# Nearest to file: format, mime, files, documents, chased, adware, disclosures, cherubim,
# Nearest to gold: silver, beneficiary, impurity, minted, congo, undertaker, ildefonso, pharmacies,
# Nearest to magazine: magazines, published, news, biography, erasable, djvu, stories, rationalists,
# Nearest to liberal: ralph, conservative, party, coalition, cnrs, hotline, democrat, unification,
# Nearest to http: www, htm, https, org, com, html, edu, cfm,
# Nearest to arts: budo, martial, muay, shaolin, obsolescence, faculty, striking, crafts,
# Nearest to mainly: also, are, cotonou, colonized, fully, nilo, vsl, atomists,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8678 0.0248 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8334 0.0240 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8448 0.0231 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8182 0.0226 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8663 0.0235 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8308 0.0237 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8538 0.0224 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8455 0.0235 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8106 0.0232 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8141 0.0227 sec/batch
# Nearest to on: the, which, in, of, by, from, an, a,
# Nearest to an: the, a, of, in, is, and, for, to,
# Nearest to with: and, to, a, the, which, in, of, by,
# Nearest to seven: one, six, eight, five, three, two, four, zero,
# Nearest to were: they, been, in, have, was, the, by, their,
# Nearest to about: zero, links, lique, updike, of, one, my, cfm,
# Nearest to some: these, such, many, in, and, are, that, based,
# Nearest to when: a, after, the, in, on, more, to, nearest,
# Nearest to pre: beginning, conquest, exported, petropavlovsk, eventually, mixtec, eas, modern,
# Nearest to file: format, mime, files, documents, chased, adware, disclosures, cherubim,
# Nearest to gold: silver, beneficiary, impurity, minted, congo, platinum, undertaker, ildefonso,
# Nearest to magazine: magazines, published, news, djvu, erasable, newspapers, biography, stories,
# Nearest to liberal: ralph, cnrs, conservative, hotline, coalition, party, democrat, unification,
# Nearest to http: www, htm, https, com, org, html, web, edu,
# Nearest to arts: budo, martial, muay, shaolin, crafts, obsolescence, faculty, striking,
# Nearest to mainly: also, are, cotonou, fully, through, vsl, colonized, atomists,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8517 0.0241 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8185 0.0234 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9622 0.0216 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9164 0.0236 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8752 0.0236 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8234 0.0227 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7943 0.0243 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8294 0.0219 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7422 0.0236 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8407 0.0228 sec/batch
# Nearest to on: the, in, by, which, of, from, an, first,
# Nearest to an: the, a, of, in, is, for, and, to,
# Nearest to with: to, and, the, a, which, in, of, by,
# Nearest to seven: six, one, eight, two, five, three, nine, zero,
# Nearest to were: they, been, have, was, taxonomies, the, in, by,
# Nearest to about: zero, my, to, lique, of, updike, links, matchbox,
# Nearest to some: these, many, such, that, have, based, in, are,
# Nearest to when: a, after, on, in, the, heft, for, nearest,
# Nearest to pre: petropavlovsk, conquest, exported, beginning, eas, mixtec, finally, dept,
# Nearest to file: format, mime, files, documents, chased, adware, cherubim, pdf,
# Nearest to gold: silver, beneficiary, congo, minted, ildefonso, platinum, impurity, undertaker,
# Nearest to magazine: magazines, published, news, biography, djvu, librarians, erasable, rationalists,
# Nearest to liberal: ralph, cnrs, conservative, isidore, eliza, tutoring, coalition, hotline,
# Nearest to http: www, htm, https, com, org, html, edu, cfm,
# Nearest to arts: budo, martial, muay, shaolin, fighting, striking, sparring, obsolescence,
# Nearest to mainly: also, are, cotonou, through, fully, vsl, which, colonized,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8422 0.0230 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8315 0.0234 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
